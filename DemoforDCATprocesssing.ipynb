# %%
import intake_dcat

catalog = intake_dcat.DCATCatalog('http://data.lacity.org/data.json', 'opendata')

# %%
list(catalog)
# Out:
# ['https://data.lacity.org/api/views/27ad-pzz3',
#  'https://data.lacity.org/api/views/29cn-rph9',
#  'https://data.lacity.org/api/views/29fd-3paw',
#  'https://data.lacity.org/api/views/2ckn-xmjp',
#  'https://data.lacity.org/api/views/2in3-5b7t',
#  'https://data.lacity.org/api/views/2qdj-cyiz',
#  'https://data.lacity.org/api/views/2t3h-my34',
#  'https://data.lacity.org/api/views/2uz8-3tj3',
#  'https://data.lacity.org/api/views/2yrw-q8tw',
#  'https://data.lacity.org/api/views/38a8-tm7u',
#  'https://data.lacity.org/api/views/3f9m-afei',
#  'https://data.lacity.org/api/views/3gwn-arjr',
#  'https://data.lacity.org/api/views/3kce-7yuf',
#  'https://data.lacity.org/api/views/3nrm-mq6k',
#  'https://data.lacity.org/api/views/3qv2-p4kj',
#  'https://data.lacity.org/api/views/42wa-pajs',
#  'https://data.lacity.org/api/views/46qe-t7np',
#  'https://data.lacity.org/api/views/4a8d-4327',
#  'https://data.lacity.org/api/views/4ca8-mxuh',
#  'https://data.lacity.org/api/views/4ftr-pfem',
# ...

# %%
catalog['https://data.lacity.org/api/views/27ad-pzz3'].read()
# Out:
#                                          Shape Geotype  GeocodingID  \
# 0     (34.03237219400006, -118.21377211799995)      pt          276
# 1     (34.19193598800007, -118.50156320399998)      pt          717
# 2    (33.928673780000054, -118.43209056299997)      pt         1439
# 3    (34.181202374000065, -118.47976491799994)      pt        15568
# 4     (33.92815815500006, -118.43313078799997)      pt        16892
# 5     (34.18008597600004, -118.48158247099997)      pt        16978
# 6         (34.179953384000044, -118.481931869)      pt        17239
# 7     (34.28017936400005, -118.37346302099996)      pt        17339
# 8    (33.928126803000055, -118.43322505399999)      pt        60178
# 9     (33.92776024400007, -118.43300855099994)      pt        60205
# 10   (33.745042488000024, -118.26103754899998)      pt        60539
# 11   (34.264123916000074, -118.61253761599994)      pt        60827
# 12   (34.113395859000036, -118.17776600099995)      pt        61078
# ...
