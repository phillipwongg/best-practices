# %%
# %matplotlib inline
import intake
from intake import open_catalog

# %% [raw]
# Creating a catalog based on a YAML file that draws on the open data and geohub data.

# %%
catalog = intake.open_catalog('local_csv.yml') #reading in new YAML file with updated data
print(list(catalog))
# Out:
# ['la_county', 'county_fuel', 'alternative_fuel', 'la_city']

# %% [raw]
# For extracting the data from the local CSVs, there are a few options: 1) Use geopandas to create new dataframes from the csv files themselves or 2) Use the existing catalog in order to pull out readable data that can be translated into a dataframe. Using geopandas is a reasonable solution, but it isn't the most efficient. The catalog created from the YAML file in the previous step already has the data in it and allows us to hide the code within the catalog without having to reproduce it. Editing the YAML file to include "driver: csv" and the "urlpath" under "args" will allow us to call upon our local csvs within the catalog. Even though geopandas only involves one or two more lines of code than the catalog, our emphasis is to increase reproducability and efficiency across departments so we should try avoiding including unnecessary boilerplate code at the beginning.
#
# As shown here, we call on the catalog to read our walking data and our physical activity data into memory.

# %%
df1 = catalog.la_county
county_bound = catalog.la_county.read()
county_bound.head()
# Out:
#    CITY  CITY_ID       CITY_TYPE       CITY_NAME      CITY_LABEL  COLOR_CODE  \
# 0   250       31  Unincorporated  Unincorporated  Unincorporated           1
# 1   250       31  Unincorporated  Unincorporated  Unincorporated           1
# 2   250       31  Unincorporated  Unincorporated  Unincorporated           1
# 3   250       31  Unincorporated  Unincorporated  Unincorporated           1
# 4   250       31  Unincorporated  Unincorporated  Unincorporated           1
#
#    ABBR  CITY_NO DESCRIPTN               URL       PHONE  OF_AREA_SM  \
# 0  UNIN        0     UNINC  www.lacounty.gov  2139744321           0
# 1  UNIN        0     UNINC  www.lacounty.gov  2139744321           0
# 2  UNIN        0     UNINC  www.lacounty.gov  2139744321           0
# 3  UNIN        0     UNINC  www.lacounty.gov  2139744321           0
# 4  UNIN        0     UNINC  www.lacounty.gov  2139744321           0
#
#   FEAT_TYPE COMMENT  SUB_TYPE  COLOR  OBJECTID
# 0      Land                 0      1         1
# 1      Land                 0      1         2
# 2      Land                 0      1         3
# 3      Land                 0      1         4
# 4      Land                 0      1         5

# %%
import pandas as pd
walking_data.to_parquet('walking_data.parquet')

# %%
df2 = catalog.county_fuel
county_fuel = catalog.county_fuel.read()
county_fuel.head()
# Out:
#             X          Y   OBJECTID  source  ext_id            cat1  \
# 0 -118.578132  34.045767  143673799     NaN     NaN  Transportation
# 1 -118.248025  34.056659  143675317     NaN     NaN  Transportation
# 2 -118.171514  34.049850  143675328     NaN     NaN  Transportation
# 3 -118.236858  34.060571  143675329     NaN     NaN  Transportation
# 4 -118.419469  33.899860  143675335     NaN     NaN  Transportation
#
#                       cat2  cat3 org_name                          Name  ...  \
# 0  County Fueling Stations   NaN      DPW                   DPW Topanga  ...
# 1  County Fueling Stations   NaN      ISD       ISD HOA (Hall of Admin)  ...
# 2  County Fueling Stations   NaN      ISD                   ISD Eastern  ...
# 3  County Fueling Stations   NaN      ISD                   ISD Alameda  ...
# 4  County Fueling Stations   NaN    B & H  B &amp; H Rosecrans Maint Ct  ...
#
#   description    zip                                    link use_type  \
# 0         NaN  91780  http://egis3.lacounty.gov/lms/?p=81375  publish
# 1         NaN  90012  http://egis3.lacounty.gov/lms/?p=76214  publish
# 2         NaN  90063  http://egis3.lacounty.gov/lms/?p=76198  publish
# 3         NaN  90012  http://egis3.lacounty.gov/lms/?p=76212  publish
# 4         NaN  90266  http://egis3.lacounty.gov/lms/?p=82549  publish
#
#     latitude   longitude              date_updated  dis_status       POINT_X  \
# 0  34.045767 -118.578132  2016-07-07T16:10:37.000Z         NaN  6.386534e+06
# 1  34.056659 -118.248025  2018-02-28T11:49:48.000Z         NaN  6.486545e+06
# 2  34.049850 -118.171514  2018-03-01T15:06:49.000Z         NaN  6.509715e+06
# 3  34.060571 -118.236858  2018-03-01T15:08:39.000Z         NaN  6.489930e+06
# 4  33.899860 -118.419469  2018-03-05T11:45:49.000Z         NaN  6.434377e+06
#
#         POINT_Y
# 0  1.839540e+06
# 1  1.843092e+06
# 2  1.840566e+06
# 3  1.844508e+06
# 4  1.786203e+06
#
# [5 rows x 31 columns]

# %%
df3 = catalog.alternative_fuel
alternative = catalog.alternative_fuel.read()
alternative.head()
# Out:
#             X          Y   OBJECTID  \
# 0 -118.465431  34.053711  143607782
# 1 -118.184720  33.958214  143607783
# 2 -118.431689  33.984869  143607784
# 3 -118.524788  34.045365  143607785
# 4 -118.490428  34.025502  143607786
#
#                                       source  ext_id            cat1  \
# 0  HSIP Freedom Alternative_Fueling_Stations     NaN  Transportation
# 1  HSIP Freedom Alternative_Fueling_Stations     NaN  Transportation
# 2  HSIP Freedom Alternative_Fueling_Stations     NaN  Transportation
# 3  HSIP Freedom Alternative_Fueling_Stations     NaN  Transportation
# 4  HSIP Freedom Alternative_Fueling_Stations     NaN  Transportation
#
#                cat2                        cat3  \
# 0  Alternative Fuel  BioDiesel Fueling Stations
# 1  Alternative Fuel  BioDiesel Fueling Stations
# 2  Alternative Fuel  BioDiesel Fueling Stations
# 3  Alternative Fuel  BioDiesel Fueling Stations
# 4  Alternative Fuel  BioDiesel Fueling Stations
#
#                                             org_name  \
# 0  National Transportation Atlas Database (NTAD) ...
# 1  National Transportation Atlas Database (NTAD) ...
# 2  National Transportation Atlas Database (NTAD) ...
# 3  National Transportation Atlas Database (NTAD) ...
# 4  National Transportation Atlas Database (NTAD) ...
#
#                                                 Name  ... description  \
# 0                                       Conserv Fuel  ...         NaN
# 1  Spirit Truck Stop - Itl Incorporated (Cudahy F...  ...         NaN
# 2                                       Usa Gasoline  ...         NaN
# 3                               Palisades Gas & Wash  ...         NaN
# 4                                         La Biofuel  ...         NaN
#
#        zip                                   link use_type   latitude  \
# 0  90049.0  http://egis3.lacounty.gov/lms/?p=4641  publish  34.053711
# 1  90201.0  http://egis3.lacounty.gov/lms/?p=4642  publish  33.958214
# 2  90292.0  http://egis3.lacounty.gov/lms/?p=4643  publish  33.984869
# 3  90272.0  http://egis3.lacounty.gov/lms/?p=4644  publish  34.045365
# 4  90408.0  http://egis3.lacounty.gov/lms/?p=4645  publish  34.025502
#
#     longitude              date_updated dis_status       POINT_X       POINT_Y
# 0 -118.465431  2010-11-01T19:50:56.000Z        NaN  6.420689e+06  1.842253e+06
# 1 -118.184720  2010-11-01T19:50:56.000Z        NaN  6.505654e+06  1.807225e+06
# 2 -118.431689  2010-11-01T19:50:56.000Z        NaN  6.430802e+06  1.817155e+06
# 3 -118.524788  2010-11-01T19:50:56.000Z        NaN  6.402693e+06  1.839305e+06
# 4 -118.490428  2010-11-01T19:50:56.000Z        NaN  6.413067e+06  1.832024e+06
#
# [5 rows x 31 columns]

# %%
df4 = catalog.la_city
city_bound = catalog.la_city.read()
city_bound.head()
city_bound.plot()
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/plotting/_core.py:1001: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0.0, right=0.0
#   ax.set_xlim(left, right)

# %% [raw]
# Once we have the data we are looking to extract from our catalog, we can then use matplotlib to visually lay out our data. We can also use various tools to conduct specific analysis on the data depending on what our hypotheses and questions of interest are.

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, figsize=(16,16))
county_bound.plot(ax=ax, color='darkgreen', alpha=0.2, linewidth=1)
city_bound.plot(ax=ax, color='blue', alpha=0.2, linewidth=1)
county_fuel.plot(ax=ax, color = 'red', alpha = 0.2, linewidth=1)
alternative.plot(ax=ax, color = 'black', alpha = 0.2, linewidth=1)

# %%
#Add in data analytics tools here for analysis of the different data sets together
